# %%
import os, sys
notebook_dir = os.getcwd()
sys.path.append(os.path.abspath(os.path.join(notebook_dir,'..')))

# %%
from scripts.object_detection import process_images
from scripts.object_detection import save_to_database
# Out:
# Downloading: "https://github.com/ultralytics/yolov5/zipball/master" to C:\Users\USER/.cache\torch\hub\master.zip
# YOLOv5  v7.0-398-g5cdad892 Python-3.13.1 torch-2.6.0+cpu CPU
#
# ...
# 100%|██████████| 40.8M/40.8M [01:37<00:00, 440kB/s]
#
# Fusing layers...
# YOLOv5m summary: 290 layers, 21172173 parameters, 0 gradients, 48.9 GFLOPs
# Adding AutoShape...

# %%
df = process_images("../data/photos")
# Out:
# 2025-02-04 19:11:53,504 - INFO - Processing image: ../data/photos\CheMed\@CheMed123_10.jpg
# C:\Users\USER\Documents\10X_Exercises\Week-7-Kara_Solutions\yolov5\models\common.py:894: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Saved 1 image to data\processed\object_detection_results2
# 2025-02-04 19:11:53,921 - INFO - Processing image: ../data/photos\CheMed\@CheMed123_11.jpg
# C:\Users\USER\Documents\10X_Exercises\Week-7-Kara_Solutions\yolov5\models\common.py:894: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Saved 1 image to data\processed\object_detection_results3
# 2025-02-04 19:11:54,194 - INFO - Processing image: ../data/photos\CheMed\@CheMed123_13.jpg
# ...

# %%
df.to_csv('../data/object_detection.csv', index=False)

# %%
save_to_database(df)
# Out:
# 2025-02-04 20:50:25,525 - ERROR - Error saving to database: (psycopg2.OperationalError) could not translate host name "{{ env_var('DB_HOST') }}" to address: Name or service not known
#
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
